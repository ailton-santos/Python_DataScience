# %% [markdown]
# <a href="https://colab.research.google.com/github/matheus-m-n/Python_DataScience/blob/main/C%C3%B3pia_de_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World
