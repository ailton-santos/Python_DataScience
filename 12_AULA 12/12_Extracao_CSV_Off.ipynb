# %% [markdown]
# #Demonstração Extração de Dados
# ###Fundamentos de Big Data e Data Science
# ###Aula 12
# ###Prof. Msc. Ailton J. Santos

# %% [markdown]
# ### Obtendo informações de dados disponibilizados pelo Site da Prefeitura de SP

# %% [markdown]
# A partir de um arquivo CSV com dados dos produtos, ler esse arquivo e separar todos os produtos contido nele.

# %%
import pandas as pd

# %% [markdown]
# Método read_csv() Lê um arquivo de valores separados por vírgula (*. csv) para um dataframe.
# Lembre-se de sempre colocar a informação juntamente com o enconding
#
# Diferença entre ISO-8859-1 e UTF-8
# - ISO-8859-1: Suporta até 256 caracteres (0 a 255, ou 0x00 a 0xFF)
# - UTF-8: Suporta até 65.536 caracteres (0 a 65535, ou 0x0000 a 0xFFFF)
#
# Obs.: Deve ser realizado o download do arquivo csv

# %%
pd.read_csv('spcine.csv', encoding='iso-8859-1')
# Out:
#                                                                                                                                                          EMPRESA;MÊS;ANO;NOME;CARGO;LOTAÇÃO;ADMISSÃO;NASCIMENTO;VENCIMENTOS;ENCARGOS;BENEFÍCIOS;OUTRAS REMUNERAÇÕES;VÍNCULO;DETALHE VÍNCULO;LIMINAR;ARQUIVO ID
# SPCine;1;2022;ANA CAROLINA DE ARAÚJO SILVA;ASSE... 6;1516                                             99;946                                              01;0;CLT: contrato por tempo indeterminado;Não...
# SPCine;1;2022;BÁRBARA ALVES TRUGILLO;COORDENADO... 88;2910                                            23;1394                                             64;0;CLT: contrato por tempo indeterminado;Não...
# SPCine;1;2022;BEATRIZ REITER SANTOS;ASSESSORA J... 42;336                                             95;541                                              64;0;CLT: contrato por tempo indeterminado;Não...
# ...
